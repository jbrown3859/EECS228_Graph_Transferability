# %%
#if using colab, do !pip install torch_geometric before running this file
from torch_geometric.datasets import Amazon
import torch
import torch.nn.functional as F
from torch_geometric.nn import MessagePassing
from torch_geometric.utils import add_self_loops, degree
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import torch.nn as nn
import pickle
import argparse
from torch.nn import Linear
import torch.nn.functional as F
from torch_geometric.nn import GATConv #GATConv



# parser = argparse.ArgumentParser()
# parser.add_argument('--hc', type=int, default = 64, help = "number of hidden channels")
# parser.add_argument('--lr', type=float, default = 0.01, help = "learning rate")
# parser.add_argument('--decay', type=float, default = 5e-4, help = "decay rate")
# parser.add_argument('--epochs', type=int, default = 1500, help = "epochs")
# args = parser.parse_args()

# parser broke the notebook for me


class params:
    def __init__(self, hidden = 64, lrate = 0.01, dec = 5e-4, epoch = 1500):
        self.hc = hidden
        self.lr = lrate
        self.decay = dec
        self.epochs = epoch
args = params()

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')


dataset = Amazon(root='/23F/228/FinalProj/Datasets/Amazon', name='Computers')
source_features = dataset[0].x.numpy()
n_in = 256
pca_source = PCA(n_components=n_in)
source_features_reduced = torch.from_numpy(pca_source.fit_transform(source_features))
source_features_reduced = source_features_reduced.to(device)


# storing the graph in the data variable
data = dataset[0]  

# some statistics about the graph.
print(data)

#train_mask
train_mask = torch.zeros(13752, dtype=torch.bool)
test_mask = torch.zeros(13752, dtype=torch.bool)
train_mask[0:10000] = True
test_mask[10001:] = True

print(f'Number of nodes: {data.num_nodes}')
print(f'Number of edges: {data.num_edges}')
print(f'Number of training nodes: {train_mask.sum()}')
print(f'Training node label rate: {int(train_mask.sum()) / data.num_nodes:.2f}')
print(f'Is undirected: {data.is_undirected()}')


# GAT model
class GAT(torch.nn.Module):
    def __init__(self, n_in, hidden_channels):
        super(GAT, self).__init__()
        torch.manual_seed(42)

        # Initialize the layers
        self.conv1 = GATConv(n_in, hidden_channels)
        self.conv2 = GATConv(hidden_channels, hidden_channels)
        self.out = Linear(hidden_channels, dataset.num_classes)
        self.hook = self.conv2.register_forward_hook(self.hook_fn)

    def hook_fn(self, module, input, output):
        self.intermediate_output = output

    def forward(self, x, edge_index):
        # First Message Passing Layer (Transformation)
        x = self.conv1(x, edge_index)
        x = x.relu()
        x = F.dropout(x, p=0.5, training=self.training)

        # Second Message Passing Layer
        x = self.conv2(x, edge_index)
        x = x.relu()
        x = F.dropout(x, p=0.5, training=self.training)

        # Output layer 
        x = F.softmax(self.out(x), dim=1)
        return x

# Initialize model
model = GAT(n_in, hidden_channels=args.hc)

# Use CPU
# device = torch.device("cpu")
model = model.to(device)
data = data.to(device)

# Initialize Optimizer
learning_rate = args.lr
decay = args.decay
optimizer = torch.optim.Adam(model.parameters(), 
                             lr=learning_rate, 
                             weight_decay=decay)
# Define loss function (CrossEntropyLoss for Classification Problems with 
# probability distributions)
criterion = torch.nn.CrossEntropyLoss()

def train():
      model.train()
      optimizer.zero_grad() 
      # Use all data as input, because all nodes have node features
      out = model(source_features_reduced, data.edge_index)  
      # Only use nodes with labels available for loss calculation --> mask
      loss = criterion(out[train_mask], data.y[train_mask])  
      loss.backward() 
      optimizer.step()
      return loss

def test():
      model.eval()
      # out = model(data.x, data.edge_index)
      out = model(source_features_reduced, data.edge_index)  
      # Use the class with highest probability.
      pred = out.argmax(dim=1)  
      # Check against ground-truth labels.
      test_correct = pred[test_mask] == data.y[test_mask]  
      # Derive ratio of correct predictions.
      test_acc = int(test_correct.sum()) / int(test_mask.sum())  
      return test_acc

losses = []

best_test_acc = 0
for epoch in range(0, args.epochs+1):
    loss = train()
    losses.append(loss)
    test_acc = test()
    if (test_acc > best_test_acc):
        best_test_acc = test_acc
        print("Test accuracy Changed", test_acc)
        torch.save(model.state_dict(), "/23F/228/FinalProj/Models/GAT_AMAZON_COMPUTERS.pth")
    if epoch % 100 == 0:
      print(f'Epoch: {epoch:03d}, Loss: {loss:.4f}')
# Out:
# Data(x=[13752, 767], edge_index=[2, 491722], y=[13752])
# Number of nodes: 13752
# Number of edges: 491722
# Number of training nodes: 10000
# Training node label rate: 0.73
# Is undirected: True
# Test accuracy Changed 0.44948013862969877
# Epoch: 000, Loss: 2.3014
# Test accuracy Changed 0.5403892295387897
# Test accuracy Changed 0.5454545454545454
# Test accuracy Changed 0.5459877366035724
# Test accuracy Changed 0.552652625966409
# Test accuracy Changed 0.5603838976272993
# Test accuracy Changed 0.5619834710743802
# Test accuracy Changed 0.5651826179685417
# Test accuracy Changed 0.6033057851239669
# Test accuracy Changed 0.642495334577446
# Test accuracy Changed 0.6686217008797654
# Test accuracy Changed 0.6758197813916289
# Test accuracy Changed 0.67821914156225
# Test accuracy Changed 0.6846174353505732
# Test accuracy Changed 0.6886163689682752
# Test accuracy Changed 0.6899493468408424
# Test accuracy Changed 0.6928818981604905
# Test accuracy Changed 0.6947480671820848
# Test accuracy Changed 0.6987470007997867
# Test accuracy Changed 0.6992801919488136
# Test accuracy Changed 0.700079978672354
# Test accuracy Changed 0.700613169821381
# Test accuracy Changed 0.7024793388429752
# Test accuracy Changed 0.7056784857371368
# Test accuracy Changed 0.7059450813116502
# Test accuracy Changed 0.7064782724606772
# Test accuracy Changed 0.7099440149293522
# Test accuracy Changed 0.7206078379098907
# Test accuracy Changed 0.7355371900826446
# Test accuracy Changed 0.7483337776592909
# Test accuracy Changed 0.7579312183417756
# Test accuracy Changed 0.7632631298320448
# Test accuracy Changed 0.7645961077046121
# Test accuracy Changed 0.7659290855771794
# Test accuracy Changed 0.7677952545987736
# Test accuracy Changed 0.768595041322314
# Test accuracy Changed 0.769128232471341
# Test accuracy Changed 0.7709944014929352
# Test accuracy Changed 0.7736603572380698
# Test accuracy Changed 0.7741935483870968
# Test accuracy Changed 0.7749933351106372
# Test accuracy Changed 0.7755265262596641
# Test accuracy Changed 0.7757931218341776
# Test accuracy Changed 0.7760597174086911
# Test accuracy Changed 0.7765929085577179
# Test accuracy Changed 0.7779258864302853
# Test accuracy Changed 0.7789922687283392
# Test accuracy Changed 0.7797920554518795
# Test accuracy Changed 0.7811250333244468
# Test accuracy Changed 0.7816582244734738
# Test accuracy Changed 0.7819248200479872
# Test accuracy Changed 0.7827246067715276
# Test accuracy Changed 0.783524393495068
# Test accuracy Changed 0.7896560917088776
# Test accuracy Changed 0.7987203412423354
# Test accuracy Changed 0.8083177819248201
# Test accuracy Changed 0.8168488403092509
# Test accuracy Changed 0.8277792588643028
# Test accuracy Changed 0.8328445747800587
# Test accuracy Changed 0.8384430818448414
# Test accuracy Changed 0.8440415889096241
# Test accuracy Changed 0.8469741402292722
# Epoch: 100, Loss: 1.6311
# Test accuracy Changed 0.8501732871234338
# Test accuracy Changed 0.8539056251666223
# Test accuracy Changed 0.8541722207411357
# Test accuracy Changed 0.8547054118901626
# Test accuracy Changed 0.8576379632098107
# Test accuracy Changed 0.8603039189549454
# Test accuracy Changed 0.8611037056784857
# Test accuracy Changed 0.8616368968275127
# Test accuracy Changed 0.8643028525726473
# Test accuracy Changed 0.8648360437216742
# Test accuracy Changed 0.8675019994668088
# Test accuracy Changed 0.8683017861903493
# Test accuracy Changed 0.8696347640629165
# Test accuracy Changed 0.8704345507864569
# Test accuracy Changed 0.8707011463609704
# Test accuracy Changed 0.8715009330845108
# Test accuracy Changed 0.8731005065315915
# Test accuracy Changed 0.8840309250866436
# Test accuracy Changed 0.8861636896827513
# Test accuracy Changed 0.8872300719808052
# Test accuracy Changed 0.887763263129832
# Test accuracy Changed 0.888296454278859
# Test accuracy Changed 0.8896294321514263
# Test accuracy Changed 0.8898960277259398
# Test accuracy Changed 0.8914956011730205
# Test accuracy Changed 0.8925619834710744
# Epoch: 200, Loss: 1.5610
# Epoch: 300, Loss: 1.5550
# Test accuracy Changed 0.8936283657691282
# Test accuracy Changed 0.8949613436416956
# Test accuracy Changed 0.895761130365236
# Epoch: 400, Loss: 1.5520
# Test accuracy Changed 0.8968275126632897
# Test accuracy Changed 0.8994934684084244
# Epoch: 500, Loss: 1.5496
# Epoch: 600, Loss: 1.5466
# Epoch: 700, Loss: 1.5493
# Epoch: 800, Loss: 1.5469
# Epoch: 900, Loss: 1.5465
# Epoch: 1000, Loss: 1.5453
# Epoch: 1100, Loss: 1.5457
# Epoch: 1200, Loss: 1.5453
# Epoch: 1300, Loss: 1.5455
# Epoch: 1400, Loss: 1.5454
# Test accuracy Changed 0.8997600639829378
# Epoch: 1500, Loss: 1.5428
